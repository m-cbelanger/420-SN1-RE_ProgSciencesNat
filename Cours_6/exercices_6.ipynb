# %% [markdown]
# # Exercices cours 6
#
# [Retour aux notes](cours_6.ipynb)
#
# ### Question 1
# Voici quelques exercices simples de manipulation de listes. À tout moment, n'hésitez pas à imprimer la liste en console (print()). Soyez attentifs aux termes utilisés dans les questions.
#
# a) Créer une liste nommée animaux qui contient des chiens, des chats, des furets, des ratons laveurs, des mulots et des grenouilles.
#
# b) Afficher la liste créée en a) dans la console
#
# c) À partir de l'index de la liste, afficher les furets seulement.
#
# d) À partir de l'index de la liste, afficher les chats, furets et les ratons laveurs.
#
# e) À partir du nom de l'animal, enlever les mulots de la liste.
#
# f) À partir de l'index, enlever les chats de la liste.
#
# g) À partir de l'index de la liste, afficher maintenant les furets.
#
# h) Ajouter les renards à la fin de la liste.
#
# i) Ajouter les orignaux à la 3e position de la liste. Afficher ensuite la liste
#
# j) Utiliser la méthode `len` pour afficher le nombre d'éléments dans la liste d'animaux.
#
# ### Question 2
# Voici une liste qui contient des masses d'éléments sur la terre. La 2e liste contient les chaînes de caractères qui décrivent les éléments associés à ces masses. À titre indicatif, les éléments sont en kg. Toutes les questions doivent se répondre avec des commandes programmées.
# ```py
# masses = [23, 56, 45.4, 32, 78, 56.9, 23.6, 100.2, 54.3]
# elements = ["valise","sac de ciment", "nourriture chien", "enfant", "adulte", "roche", "télévision", "piano", "haltères"]
# ```
#
# a) Combien d'éléments contiennent chacune des 2 listes? Utilisez la méthode qui le calcule. Pour voir la réponse, mettre le calcul dans un print.
#
# b) Qu'est-ce qui se trouve à la 8e position des listes? Elles sont associées, mettez-les dans une phrase de type: Le 5e élément est : ... . Cest élément pèse ... kg.
#
# c) Quelle est la moyenne des masses? L'écart-type? Arrondir à 2 décimales
#
# d) On souhaite enlever l'enfant et l'adulte de la liste. Pour ce faire:
#
# 1. Trouver l'index de l'adulte dans la liste elements et affectez la valeur dans une variable appellée mon_index.
# 2. Utiliser mon_index pour retirer les éléments qui correspondent à l'enfant dans les 2 listes.
# 3. Trouver l'index de l'enfant dans la listse elements et affectez la valeur dans mon_index (on écrasera la valeur)
# 4. Utiliser mon_index pour retirer les éléments qui correspondent à l'adulte dans les 2 listes.
#
# e) On va utiliser une commande qui vérifie si un item fait partie d'une liste, avec une structure conditionnelle. Par exemple:
#
# ```py
# if "valise" in elements:
#     #votre code ici
# ```
# Voici le traitement à faire dans une structure conditionnelle:
#
# 1. Si la valise est dans la liste:
#
#     - Trouver son index et le stocker dans une variable du nom de votre choix.
#     - Ensuite, accéder à la masse qui lui correspond (même index dans la liste masses) et la multiplier par 9.8 pour stocker le résultat dans la nouvelle variable nommée poids.
#     - Sinon si la valise n'existe pas, insérer-là avec une masse de 34 à la fin des listes correspondantes.
#
# 2. Essayez le code ci-haut avec le mot "voiture" et 2000kg
#
# > Note: comment auriez-vous pu adapter le code ci-haut pour ne pas avoir à changer les mots valise et voiture à plein d'endroits?
#
# > Note2: Est-ce que ça fonctionne si on essai avec Valise plutôt que valise?
#
# f) L'exercice suivant sert à retirer les valeurs extrêmes.
#
# 1. trouver la valeur minimale de masses et la stocker dans une variable du nom de votre choix.
# 2. trouver la valeur maximale de masses et la stocker dans une variable du nom de votre choix.
# 3. supprimer les 2 éléments et leurs masses associées
# > Note: attention, l'ordre dans lequel vous faites ces étapes fera potentiellement une différence! Pouvez-vous dire laquelle?
#
# ### Question 3
#
# On peut faire des listes avec des valeurs de différents types. Voici un exemple:
#
# ```py
# ma_variable = "mot mystère"
# liste_mixte = ["neige", 28, "soleil", 55.6, 26, -9, ma_variable, 0.22, (9,8), "pluie", [4,5,6]]
#
# ```
#
#
# 1. calculer le nombre d'éléments dans la liste et conserver la valeur dans une variable nommée `n`
# 2. trouver un nombre aléatoire qui pige un élément dans la liste. Voici le code pour piger un nombre aléatoire:
# ```py
# import random #à mettre généralement au début du fichier
# nombre_aleatoire = random.randint(1, n)
#
# ```
# 3. faire un print de l'élément trouvé à la position n dans la liste_mixte. Par exemple, si vous pigez 3, on devrait voir "soleil" en console.
#
# 4. Vérifier si l'élément pigé est un nombre ou pas. On utilise entre autres la commande suivante pour trouver la réponse à la question. S'il s'agit d'un nombre, faire print("C'est un nombre"), sinon, print("Ce n'est pas un nombre")
# ```py
# isinstance(element, (int, float))
# ```
# Les nombres sont des entiers (int) **ou** des nombres flottants (float).
#
# > Note: c'est normal que le logiciel ne reconnaisse pas (9,8) comme un nombre, il s'agit d'un `tuple`, une autre structure de stockage de données. Si s'agit donc d'un `tuple` de nombres et non juste d'un nombre. Même chose pour la liste dans la liste.
#
# 5. Ajoutons des étapes à la structure conditionnelle de la sous-question ci-haut (copier-la d'abord). Si on a un chiffre, non seulement on imprime que c'est un chiffre mais on vérifie aussi **si c'est un nombre plus petit que 1**. Si oui, on **efface** l'élément de la liste.
#
# 6. Ajoutons encore des étapes dans la structure conditionnelle. Si on n'a pas un nombre, on va faire une condition "sinon si" qui vérifie si c'est une chaine de caractères. Si oui, on va ajouter la chaîne de caractères "-vérifié" au mot déjà présent dans la liste. On imprime aussi que "C'est une chaîne de caractères". Le reste du temps, on imprime que "Ce n'est pas un nombre ni une chaîne de caractères".

# %% [markdown]
# # [Solutions](solutions_6.ipynb)
