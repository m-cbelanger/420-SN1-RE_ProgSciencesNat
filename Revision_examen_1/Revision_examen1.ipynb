# %% [markdown]
# # Révision examen 1
#
#
# ## Section de questions théoriques
#
#
# ### Question 1
#
# Vrai ou faux?
#
# a) Dans la structure conditionnelle, on peut avoir seulement un if (sans elif ni else).
#
# b) Si on déclare une variable pendant qu'on est dans une fonction, celle-ci ne sera plus utilisable à l'extérieur de la fonction.
#
# c) Le nom de variable "3eVitesse" est valide.
#
#
# d) Une fonction ne fait rien tant qu'elle n'est pas appelée.
#
# e) il est possible d'utiliser une varriable globale dans une fonction et à l'extérieur d'une fonction.
#
#
# ### Question 2
#
# a) Pourquoi il est avantageux de faire des fonctions?
#
# b) Quelle est la façon de faire pour pouvoir utiliser et modifier une variable globale dans une fonction?
#
# c) Qu'est-ce qui apparaîtra dans la console si on lance ce bout de code:
#
# ```py
# poids = 34
# poids_lbs = poids*2.2
# print("poids_lbs")
# ```
#
# d) En roulant ce bout de code:
# ```py
# def fonction(a,b):
#     resultat = a * b
#     return resultat
#
# print(resultat)
#
# ```
# on obtient un message d'erreur. Pourquoi?
# ![erreur1.PNG](img/erreur1.PNG)
#
#
#
# e) Dans la structure conditionnelle suivante, quels retours aurons-nous (regarder les 3 appels après le code)
# ```py
# def chiffre_mystere(le_chiffre):
#     valeur = 0
#     if le_chiffre > 0 and le_chiffre < 6:
#         valeur = 1
#     elif le_chiffre <= 15:
#         valeur = 2
#     elif le_chiffre == 14:
#         valeur = 3
#     else:
#         valeur = 4
#     return valeur
#
# print(chiffre_mystere(2))
# print(chiffre_mystere(-10))
# print(chiffre_mystere(14))
# ```
#
# f) À la question précédente, est-ce possible d'avoir la valeur 4 en retour? Si oui, donnez un exemple de chiffre à passer à la fonction pour que ça retourne 4, sinon, expliquez pourquoi.
#
# g) Refaire la question e) en changeant le "and" pour un "or". Que constatez-vous?
#
# h) Voici un petit bout de code:
# ```py
# description = espece + couleur
# espece = "Chat"
# couleur = "noir"
#
# print(description)
# ```
#
# Expliquez pourquoi vous obtenez une erreur en rouge dans la console:
#
# NameError: name 'espece' is not defined
#
# i) Nommez un avantage à utiliser des variables globales plutôt que locales.
#
# j) Dans la fonction de la puissance calorifique, pourquoi on mets des valeurs après les paramètres?
# ```py
# def fonction (P=None, u= None, r= None):
# ...
# ```
#
# k) Dans l'exécution ci-dessous, écrire des numéros à côté des lignes selon l'endroit où est l'exécution. Le numéro 1 est placé pour vous:
#
# ![retraite.PNG](img/retraite.PNG)
#
#
#
# ## Section de questions de programmation avec logiciel
#
# ### Toutes les questions des cours 1 - 2 - 3 est des Exercices 1 - 2 - 3 sont des pratiques pour les questions d'examen. Si la question est longue, il peut vous être demandé de faire le code pour une partie seulement.
#
#
# ### Quelques question supplémentaires, mais cette liste n'est pas exhaustive.
#
# ### Question 3
#
# a) Faire une fonction qui prend en paramètre 2 valeurs et qui **retourne** la valeur manquante dans la formule de pH: (note: le symbole + à côté du H fait partie de son nom, il n'y a pas d'opérations associée à ce +).
#
# $$
# pH = log(\frac{1}{H^+})
# $$
#
# b) Présentement (2024), la taxes sur les produits et services au Québec est de 14,975%. Mettre cette valeur dans une variable globale et l'utiliser dans une fonction qui calcule et retourne la valeur finale de vente d'un article. Dans cette fonction, ajouter aussi la possibilité de mettre un rabais (optionnel). (Réfléchir à un nom significatif pour la fonction, aux paramètres à passer lors de l'appel)
#
#
#
# ## [CORRIGÉ](Revision_Examen-CORRIGE.ipynb)
