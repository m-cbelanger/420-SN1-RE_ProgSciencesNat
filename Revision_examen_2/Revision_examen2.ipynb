# %% [markdown]
# # Révsion examen 2
#
# Les cours à l'examen sont principalement les cours 6 et cours 7. Les notions à savoir et comprendre sont:
#
# - Déclarer une liste
# - Récupérer une valeur dans une liste avec l'index de l'élément (liste[i])
# - Faire une boucle for:
#     - de type for element in liste (si on n'a PAS besoin de l'index pour une opération, un remplacement ou une suppression).
#     - de type for i in range() (si on a besoin de l'index).
#     - comprendre la possibilité de mettre plusieurs traitements dans le corps d'une boucle.
# - Gérer les conditions (if, elif, else) et les compteurs dans une boucle
# - Comprendre les opérations dans le tableau des opéartions possibles sur les listes (feuille de formules)
# - Comprendre comment appeler une fonction simple dans une boucle.
# - Comprendre POURQUOI il est précaire de faire des remove PENDANT qu'on parcoure une liste.
# - Comprendre POURQUOI il faut enlever les valeurs selon leur index en ordre décroissant si on veut prendre la méthode 2.
# - Comprendre comment REMPLACER une valeur dans une liste (à l'extérieur d'une boucle tout comme à l'intéreur d'une boucle).
# - Savoir faire des décompte dans une liste selon une condition.
# - Savoir passer une valeur à une fonction déjà donnée lors d'une boucle.
#
#
# Les exercices ci-dessous survolent les concepts vus dans les cours 6,7 et 7b. Il faut aussi faire les exercices du cours 7 et le TP2 pour s'assurer de bien comprendre.
#
#
# # Exercices
#
# Dans cette section, les exercices proposés sont proposé en ordre, du plus simple au plus complexe. Des questions de compréhension sont placées au travers. Le format de l'examen sera similaire (code et questions de compréhension entrecoupées).
#
#
# ### Question 1 (liste seule)
# Dans une liste comme celle-ci:
#
# ```py
# ma_liste = [9,3,5,3,7,8,3,6,12,10]
# ```
# a) Avec une commande (code), montrer (print) combien d'éléments se trouvent dans la liste.
#
# b) AJOUTER la valeur 7 à la fin de ma_liste.
#
# c) Enlever la valeur à la position 3 (le chiffre 5 dans ce cas-ci) en utilisant l'index (il n'est pas nécessaire de calculer l'index, trouvez-le avec vos yeux)
#
# d) Si on fait le code suivant:
#
# ```py
# index = ma_liste.index(3)
# ```
#
#     i) Que devrait contenir la variable index?
#     ii) Si on veut faire une boucle et repérer les valeurs une par une (avoir leur index), pourquoi aurait-on des embuches (problèmes)?
#     iii) Dans quelles circonstances (pour quel type de liste) ça serait utile de trouver l'index en faisant ma_liste.index(...) pendant une boucle?
#
# e) Faire une boucle qui parcoure cette liste pour trouver le double de chacun des nombres présents et les montrer en console (print). Est-ce qu'on prend l'approche `in` ou l'approche `range`?
#
# f) Faire une boucle qui parcoure cette liste pour trouver le double de chacun des nombres présents et les remplacer dans la liste. Est-ce qu'on prend l'approche `in` ou l'approche `range`?
#
# g) Faire une boucle qui parcoure cette liste pour identifier les nombres qui sont divisibles par 3 (modulo 3 == 0) et les copier dans une nouvelle liste à part. Est-ce qu'on prend l'approche `in` ou l'approche `range`?
#
# h) Retirer les valeurs impaires de cette liste. Il existe au moins 2 stratégies valides. Reprendre la liste initiale pour faire cet exercice.
#
#
#
#
# ### Question 2 (listes associées)
#
# Voici 2 listes associées qui représentent la température d'une piscine en celsius et l'heure de la journée à laquelle la mesure a été prise. Toutes les questions ci-dessous doivent être faite avec du code, sans intervention de l'humain, c'est-à-dire que vous ne pouvez pas intervenir en écrivant des données que vous voyez, ça dois être variable et fonctionner pour d'autres listes dans le futur.
#
#
# ```py
# import numpy
# temperature = [25.3 , 26.1 , 26.3 , 26.1 , 26.1 , 81.1 , 26.8 , 26.4 , 26.1 , 26.1]
# heure_jour  = ["5:00","6:35","7:50","10:02","10:45","12:12","13:15","16:03","17:38","18:20"]
# ```
#
# a) Quelle est l'étendue (différence entre la plus haute et la plus basse) de température prise dans cette journée? Ça vous semble normal comme réponse?
#
#
#
# b) Combien de fois avons-nous pris la température 26.1?
#
# c) Faire une liste des heures auxquelles les températures étaient à 26.1
#
# d) Quelle est la moyenne et l'écart-type de températures?
#
# e) En a) il y a une valeur qui a été entrée en Fahrenheit plutôt qu'en celsius. Trouvez-là à l'aide d'une condition (si la température est au-dessus de (la moyenne + 2 x ecart_types), c'est une valeur qui n'est assurément pas "normale". Trouver une façon sécuritaire **d'enlever** cette valeur et l'heure à laquelle elle a été prise de sorte que votre code soit réutilisable (donc fonctionne pour enlever des valeurs pas normales d'autres listes de températures).
#
# f) Voici la fonction qui transforme les degrés celsius en Fahrenheit:
#
# ```py
# def conversion(degre):
#     fahrenheit = degre * 9/5 + 32
#     return fahrenheit
# ```
#
# Faire une boucle qui parcoure la liste de température et qui **remplace** la valeur dans la liste par la valeur en Fahrenheit en utilisant la fonction.
#
#
# ### Question 3 (listes mixtes)
#
# Voici une liste contenant plusieurs types de variables (entiers (int), nombres décimaux (float), chaîne de caractères (str)). Elle n'a pas de liste associée et a toujours potentiellement des doublons.
#
# ```py
# liste_melangee = ["10:40", 8, 9.1, "voiture", "voiture",[5,10,-8.4], 400, -6]
# ```
#
# a) Faire 3 liste nouvelles dans lesquelles copier distinctement les entiers, les chaînes et les nombres décimaux.
#
# b) Faire une boucle pour faire le tri de cette liste_mixte.
#
# c) Faire un décompte du nombre de chiffres (floats et int) en parcourant la liste_mixte dans une boucle.
